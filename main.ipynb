# %%
from copyreg import pickle

import requests
from nbconvert.preprocessors.extractoutput import platform_utf_8_encode
from pyparsing.diagram import template

# Example: Get Dodgers roster
url = "https://statsapi.mlb.com/api/v1.1/game/716463/feed/live"
response = requests.get(url)
data = response.json()
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import requests
#       2 from nbconvert.preprocessors.extractoutput import platform_utf_8_encode
# ----> 3 from pyparsing.diagram import template
#       5 # Example: Get Dodgers roster
#       6 url = "https://statsapi.mlb.com/api/v1.1/game/716463/feed/live"
#
# File ~/miniconda3/envs/mlb/lib/python3.11/site-packages/pyparsing/diagram/__init__.py:5
#       2 from __future__ import annotations
#       4 import itertools
# ----> 5 import railroad
#       6 import pyparsing
#       7 import dataclasses
#
# ModuleNotFoundError: No module named 'railroad'

# %%
data['liveData']
# Out:
# dict_keys(['plays', 'linescore', 'boxscore', 'decisions', 'leaders'])

# %%
import pandas as pd
import json
import requests
def process_endpoint_url(endpoint_url, pop_key=None):
  """
  Fetches data from a URL, parses JSON, and optionally pops a key.

  Args:
    endpoint_url: The URL to fetch data from.
    pop_key: The key to pop from the JSON data (optional, defaults to None).

  Returns:
    A pandas DataFrame containing the processed data
  """
  json_result = requests.get(endpoint_url).content

  data = json.loads(json_result)

   # if pop_key is provided, pop key and normalize nested fields
  if pop_key:
    df_result = pd.json_normalize(data.pop(pop_key), sep = '_')
  # if pop_key is not provided, normalize entire json
  else:
    df_result = pd.json_normalize(data)

  return df_result

# %%
teams_endpoint_url = 'https://statsapi.mlb.com/api/v1/teams?sportId=1'

teams = process_endpoint_url(teams_endpoint_url, 'teams')

# %%
index=['id','league_id','teamCode','teamName','league_name']
teams1 = teams[index]
teams1['logo_link'] = teams1['id'].apply(lambda x: f'https://www.mlbstatic.com/team-logos/{x}.svg')
# Out:
# /tmp/ipykernel_6436/345020345.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teams1['logo_link'] = teams1['id'].apply(lambda x: f'https://www.mlbstatic.com/team-logos/{x}.svg')

# %%
len(teams)
# Out:
# 30

# %%
teams1
# Out:
#      id  league_id teamCode   teamName      league_name  \
# 0   133        103      ath  Athletics  American League
# 1   134        104      pit    Pirates  National League
# 2   135        104      sdn     Padres  National League
# 3   136        103      sea   Mariners  American League
# 4   137        104      sfn     Giants  National League
# 5   138        104      sln  Cardinals  National League
# 6   139        103      tba       Rays  American League
# 7   140        103      tex    Rangers  American League
# 8   141        103      tor  Blue Jays  American League
# 9   142        103      min      Twins  American League
# 10  143        104      phi   Phillies  National League
# 11  144        104      atl     Braves  National League
# 12  145        103      cha  White Sox  American League
# 13  146        104      mia    Marlins  National League
# 14  147        103      nya    Yankees  American League
# 15  158        104      mil    Brewers  National League
# ...

# %%
season = 2024 # @param {type:"integer"}

# Can change season to get other seasons' games info
schedule_endpoint_url = f'https://statsapi.mlb.com/api/v1/schedule?sportId=1&season={season}'

schedule_dates = process_endpoint_url(schedule_endpoint_url, "dates")

games = pd.json_normalize(
    schedule_dates.explode('games').reset_index(drop = True)['games'])

# %%
games.keys()
# Out:
# Index(['gamePk', 'gameGuid', 'link', 'gameType', 'season', 'gameDate',
#        'officialDate', 'isTie', 'gameNumber', 'publicFacing', 'doubleHeader',
#        'gamedayType', 'tiebreaker', 'calendarEventID', 'seasonDisplay',
#        'dayNight', 'scheduledInnings', 'reverseHomeAwayStatus',
#        'inningBreakLength', 'gamesInSeries', 'seriesGameNumber',
#        'seriesDescription', 'recordSource', 'ifNecessary',
#        'ifNecessaryDescription', 'status.abstractGameState',
#        'status.codedGameState', 'status.detailedState', 'status.statusCode',
#        'status.startTimeTBD', 'status.abstractGameCode',
#        'teams.away.leagueRecord.wins', 'teams.away.leagueRecord.losses',
#        'teams.away.leagueRecord.pct', 'teams.away.score', 'teams.away.team.id',
#        'teams.away.team.name', 'teams.away.team.link', 'teams.away.isWinner',
#        'teams.away.splitSquad', 'teams.away.seriesNumber',
#        'teams.home.leagueRecord.wins', 'teams.home.leagueRecord.losses',
# ...

# %%
games['gamePk'].iloc[-1]
# len(games['gamePk'])
# Out:
# np.int64(775296)

# %%
import pickle as pkl
with open('data.pkl','rb') as f:
    player_hitting = pkl.load(f)

# %%
for i in range(2117,len(games['gamePk'])):
    game_pk = games['gamePk'].iloc[i]
    single_game_feed_url = f'https://statsapi.mlb.com/api/v1.1/game/{game_pk}/feed/live'
    print(game_pk)

    single_game_info_json = json.loads(requests.get(single_game_feed_url).content)
    for j in range(len(single_game_info_json['liveData']['plays']['allPlays'])):
        id = single_game_info_json['liveData']['plays']['allPlays'][j]['matchup']['batter']['id']
        if not(id in player_hitting.keys()):
            player_hitting[id]=[]
        hit = []
        for k in range(len(single_game_info_json['liveData']['plays']['allPlays'][j]['playEvents'])):
            if 'isInPlay' in single_game_info_json['liveData']['plays']['allPlays'][j]['playEvents'][k]['details'].keys() and single_game_info_json['liveData']['plays']['allPlays'][j]['playEvents'][k]['details']['isInPlay']:
                hit.append((single_game_info_json['liveData']['plays']['allPlays'][j]['playEvents'][k]['playId'],single_game_info_json['liveData']['plays']['allPlays'][j]['playEvents'][k]['hitData']))
        player_hitting[id]+=hit
# Out:
# 747172
# 746441
# 747005
# 745546
# 745060
# 746683
# 746926
# 745787
# 745149
# 746365
# 746763
# 745958
# 746197
# 747167
# 745389
# 745309
# 745061
# 747003
# 745543
# 745789
# 746764
# 745960
# 745148
# 747170
# 746925
# 746678
# 746363
# 745386
# 746198
# 745306
# 746607
# 746442
# 747092
# 746849
# 746196
# 746845
# 746443
# 745471
# 744825
# 745719
# 746605
# 746679
# 747089
# 744986
# 746354
# 745875
# 746193
# 745631
# 745387
# 745224
# 745714
# 746846
# 744823
# 746440
# 745474
# 744987
# 745876
# 746608
# 746681
# 746358
# 747087
# 745388
# 745636
# 746194
# 745225
# 746680
# 745468
# 747088
# 745718
# 744826
# 746606
# 746439
# 746356
# 745879
# 744979
# 746191
# 745627
# 745384
# 745222
# 746844
# 745184
# 746600
# 746038
# 744821
# 744982
# 746847
# 746276
# 745628
# 746116
# 745467
# 746033
# 744817
# 744901
# 747086
# 745141
# 744983
# 746840
# 746273
# 746519
# 745221
# 745629
# 746120
# 746602
# 745713
# 746604
# 746602
# 746842
# 744981
# 745630
# 745709
# 745713
# ...

# %%
single_season_players_url = f'https://statsapi.mlb.com/api/v1/sports/1/players?season={season}'

players = process_endpoint_url(single_season_players_url, 'people')
# Out:
# 0       671096
# 1       682928
# 2       650556
# 3       547989
# 4       677800
#          ...
# 1449    691172
# 1450    670871
# 1451    518595
# 1452    676969
# 1453    594798
# Name: id, Length: 1454, dtype: int64

# %%
players
# Out:
# Index(['id', 'fullName', 'link', 'firstName', 'lastName', 'primaryNumber',
#        'birthDate', 'currentAge', 'birthCity', 'birthStateProvince',
#        'birthCountry', 'height', 'weight', 'active', 'useName', 'useLastName',
#        'middleName', 'boxscoreName', 'gender', 'isPlayer', 'isVerified',
#        'draftYear', 'mlbDebutDate', 'nameFirstLast', 'nameSlug',
#        'firstLastName', 'lastFirstName', 'lastInitName', 'initLastName',
#        'fullFMLName', 'fullLFMName', 'strikeZoneTop', 'strikeZoneBottom',
#        'currentTeam_id', 'currentTeam_link', 'primaryPosition_code',
#        'primaryPosition_name', 'primaryPosition_type',
#        'primaryPosition_abbreviation', 'batSide_code', 'batSide_description',
#        'pitchHand_code', 'pitchHand_description', 'nameMatrilineal',
#        'nickName', 'pronunciation', 'nameTitle', 'nameSuffix',
#        'lastPlayedDate'],
#       dtype='object')

# %%
for i,e in enumerate(player_hitting.keys()):
    try:
        print(players.iloc[players['id'].tolist().index(e)]['mlbDebutDate'])
        if '2024' in players.iloc[players['id'].tolist().index(e)]['mlbDebutDate']:
            print(e)
    except:
        pass
# Out:
# 2014-06-29
# 2014-07-24
# 2022-07-31
# 2016-08-12
# 2015-05-24
# 2019-09-02
# 2024-04-16
# 681624
# 2019-03-28
# 2013-08-20
# 2020-07-26
# 2020-09-04
# 2021-04-01
# 2024-03-20
# 701538
# 2022-08-26
# 2022-04-07
# 2023-04-18
# 2024-08-16
# 700242
# 2024-07-31
# 676439
# 2023-08-30
# 2024-03-20
# 688363
# 2023-06-21
# 2024-09-16
# 694377
# 2024-08-16
# 694359
# 2018-07-21
# 2022-06-28
# 2022-05-30
# 2013-09-04
# 2023-09-08
# 2024-03-28
# 694671
# 2019-04-29
# 2022-07-15
# 2023-09-01
# 2022-08-22
# 2024-08-25
# 694355
# 2020-07-24
# 2020-09-11
# 2014-05-22
# 2022-06-04
# 2022-05-30
# 2024-04-05
# 679822
# 2020-09-04
# 2017-04-06
# 2024-04-09
# 673995
# 2023-08-07
# 2024-09-28
# 687957
# 2024-06-24
# 680769
# 2024-09-06
# 660758
# 2013-08-14
# 2017-05-28
# 2021-04-02
# 2017-05-13
# 2022-05-17
# 2023-05-04
# 2023-05-05
# 2023-09-06
# 2023-09-11
# 2024-05-22
# 676679
# 2018-09-08
# 2024-05-04
# 682868
# 2023-04-30
# 2012-09-30
# 2011-09-03
# 2019-05-14
# 2018-04-21
# 2023-05-05
# ...

# %%
for i in player_hitting.keys():
    a=[]
    for j in player_hitting[i]:
        if len(j[1])!=4:
            a.append(j)
    player_hitting[i]=a

# %%
count=0
for i in player_hitting.keys():
    if player_hitting[i] == []:
        count+=1
count
# Out:
# 491

# %%
import copy
keys = list(player_hitting.keys())
for i in keys:
    if player_hitting[i]==[]:
        player_hitting.pop(i)

# %%
count=0
for i in player_hitting.keys():
    if player_hitting[i] == []:
        count+=1
count
# Out:
# 0

# %%
import pickle as pkl
with open('data_cleaned.pkl','wb') as f:
    pkl.dump(player_hitting,f)

# %%
player_hitting[668752]
# Out:
# [('f0562245-9d21-46ad-bc87-6e97fb4fd941',
#   {'launchSpeed': 104.9,
#    'launchAngle': -26.0,
#    'totalDistance': 5.0,
#    'trajectory': 'ground_ball',
#    'hardness': 'medium',
#    'location': '4',
#    'coordinates': {'coordX': 142.81, 'coordY': 130.94}}),
#  ('49c79f69-23ec-4a11-b60e-e6e27a2891f5',
#   {'launchSpeed': 68.8,
#    'launchAngle': -62.0,
#    'totalDistance': 3.0,
#    'trajectory': 'ground_ball',
#    'hardness': 'soft',
#    'location': '3',
#    'coordinates': {'coordX': 143.97, 'coordY': 173.79}}),
#  ('a210512f-3f70-48e4-8711-0cd765a34dfd',
#   {'launchSpeed': 69.5,
#    'launchAngle': 24.0,
#    'totalDistance': 195.0,
#    'trajectory': 'line_drive',
#    'hardness': 'medium',
#    'location': '7',
#    'coordinates': {'coordX': 71.28, 'coordY': 130.73}})]

# %%
player_hitting[518692]
# Out:
# [('07482606-0056-0013-000c-f08cd117d70a',
#   {'trajectory': 'line_drive',
#    'hardness': 'medium',
#    'location': '7',
#    'coordinates': {'coordX': 34.76, 'coordY': 74.15}}),
#  ('07482606-0236-0013-000c-f08cd117d70a',
#   {'trajectory': 'ground_ball',
#    'hardness': 'medium',
#    'location': '6',
#    'coordinates': {'coordX': 122.93, 'coordY': 155.23}}),
#  ('07482606-0386-0013-000c-f08cd117d70a',
#   {'trajectory': 'fly_ball',
#    'hardness': 'medium',
#    'location': '9',
#    'coordinates': {'coordX': 158.4, 'coordY': 46.28}}),
#  ('07482326-0246-0013-000c-f08cd117d70a',
#   {'trajectory': 'fly_ball',
#    'hardness': 'medium',
#    'location': '7',
#    'coordinates': {'coordX': 53.7, 'coordY': 74.59}}),
#  ('35983f02-fc0c-474a-87b1-7b7b2b3ed8c5',
#   {'launchSpeed': 96.1,
#    'launchAngle': 3.0,
#    'totalDistance': 69.0,
#    'trajectory': 'ground_ball',
#    'hardness': 'medium',
#    'location': '9',
#    'coordinates': {'coordX': 188.21, 'coordY': 107.33}}),
# ...

# %%
player_hitting[692416]
# Out:
# [('07480436-0726-0013-000c-f08cd117d70a',
#   {'trajectory': 'ground_ball',
#    'hardness': 'medium',
#    'location': '5',
#    'coordinates': {'coordX': 114.66, 'coordY': 186.13}}),
#  ('0414969c-9bb2-454a-8923-a192fe62679c',
#   {'launchSpeed': 79.6,
#    'launchAngle': -44.0,
#    'totalDistance': 4.0,
#    'trajectory': 'ground_ball',
#    'hardness': 'medium',
#    'location': '5',
#    'coordinates': {'coordX': 109.43, 'coordY': 169.02}})]

# %%
count = 0
for i in player_hitting:
    if player_hitting[i] == []:
        count+=1
print(count)
# Out:
# 147

# %%
season = 2024 # @param {type:"integer"}

single_season_players_url = f'https://statsapi.mlb.com/api/v1/sports/1/players?season={season}'

players = process_endpoint_url(single_season_players_url, 'people')
len(players)
# Out:
# 1454

# %%
game_pk = games['gamePk'].iloc[-1]

single_game_feed_url = f'https://statsapi.mlb.com/api/v1.1/game/{game_pk}/feed/live'

single_game_info_json = json.loads(requests.get(single_game_feed_url).content)

# %%
len(single_game_info_json['liveData']['plays']['allPlays'])
# Out:
# 89

# %%
single_game_info_json['liveData'].keys()
# Out:
# dict_keys(['plays', 'linescore', 'boxscore', 'decisions', 'leaders'])

# %%
single_game_info_json['liveData']['plays'].keys()
# Out:
# dict_keys(['allPlays', 'currentPlay', 'scoringPlays', 'playsByInning'])

# %%
single_game_info_json['liveData']['plays']['allPlays'][0]['matchup']['batter']['id']
# Out:
# 660271

# %%
single_game_info_json['liveData']['plays']['allPlays'][0]['playEvents'][0].keys()
# Out:
# dict_keys(['details', 'count', 'index', 'startTime', 'endTime', 'isPitch', 'type', 'player'])

# %%
single_game_info_json['liveData']['plays']['allPlays'][8]['playEvents'][0].keys()
# Out:
# dict_keys(['details', 'count', 'pitchData', 'hitData', 'index', 'playId', 'pitchNumber', 'startTime', 'endTime', 'isPitch', 'type'])

# %%
single_game_info_json['liveData']['plays']['allPlays'][0]['playEvents'][0]['player']['id']  # player id
# Out:
# 660271

# %%
single_game_info_json['liveData']['plays']['allPlays'][0]['playEvents'][3]['playId']    # play id
# Out:
# '1fb1fa95-e905-4a08-a9a9-7d19713b547b'

# %%
def print_json_tree(data, indent=0):
    """递归打印 JSON 的键的树状结构"""
    if isinstance(data, dict):
        for key, value in data.items():
            print("  " * indent + str(key))
            print_json_tree(value, indent + 1)
    elif isinstance(data, list):
        for index, item in enumerate(data):
            print("  " * indent + f"[{index}]")
            print_json_tree(item, indent + 1)
print_json_tree(single_game_info_json['liveData']['plays'])
# Out:
# allPlays
#   [0]
#     result
#       type
#       event
#       eventType
#       description
#       rbi
#       awayScore
#       homeScore
#       isOut
#     about
#       atBatIndex
#       halfInning
#       isTopInning
#       inning
#       startTime
#       endTime
#       isComplete
#       isScoringPlay
#       hasReview
#       hasOut
#       captivatingIndex
#     count
#       balls
#       strikes
#       outs
#     matchup
#       batter
#         id
#         fullName
#         link
#       batSide
#         code
#         description
#       pitcher
#         id
#         fullName
#         link
#       pitchHand
#         code
#         description
#       batterHotColdZones
#       pitcherHotColdZones
#       splits
#         batter
#         pitcher
#         menOnBase
#     pitchIndex
#       [0]
#     actionIndex
#       [0]
#       [1]
#       [2]
#     runnerIndex
#       [0]
#     runners
#       [0]
#         movement
#           originBase
# ...

# %% [markdown]
# ## test request

# %%
import requests
requests.get('https://on-request-example-ktlgkxzqla-uc.a.run.app/')
# Out:
# <Response [200]>
